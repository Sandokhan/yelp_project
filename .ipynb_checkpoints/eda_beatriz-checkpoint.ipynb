# %% [markdown]
# ### EDA
# Firstly let's explore the data!

# %%
#imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read the data
businness = pd.read_json('datasets/yelp_academic_dataset_business.json', lines=True)

# %%
#see the first 5 rows of the dataset
businness.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1  87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2             5255 E Broadway Blvd         Tucson    AZ       85711
# 3                      935 Race St   Philadelphia    PA       19107
# 4                    101 Walnut St     Green Lane    PA       18054
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
# 2  32.223236 -110.880452    3.5            22        0
# ...

# %%
#see info
businness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150346 entries, 0 to 150345
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   business_id   150346 non-null  object
#  1   name          150346 non-null  object
#  2   address       150346 non-null  object
#  3   city          150346 non-null  object
#  4   state         150346 non-null  object
#  5   postal_code   150346 non-null  object
#  6   latitude      150346 non-null  float64
#  7   longitude     150346 non-null  float64
#  8   stars         150346 non-null  float64
#  9   review_count  150346 non-null  int64
#  10  is_open       150346 non-null  int64
#  11  attributes    136602 non-null  object
#  12  categories    150243 non-null  object
#  13  hours         127123 non-null  object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 16.1+ MB

# %%
#show dtypes
businness.dtypes
# Out:
# business_id      object
# name             object
# address          object
# city             object
# state            object
# postal_code      object
# latitude        float64
# longitude       float64
# stars           float64
# review_count      int64
# is_open           int64
# attributes       object
# categories       object
# hours            object
# dtype: object

# %%
#show columns
businness.columns
# Out:
# Index(['business_id', 'name', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open',
#        'attributes', 'categories', 'hours'],
#       dtype='object')

# %%
#count null values
businness.isna().sum()
# Out:
# business_id         0
# name                0
# address             0
# city                0
# state               0
# postal_code         0
# latitude            0
# longitude           0
# stars               0
# review_count        0
# is_open             0
# attributes      13744
# categories        103
# hours           23223
# dtype: int64

# %%
#city value counts: top 5
city_valuecounts = businness.city.value_counts()[0:5]
city_valuecounts
# Out:
# city
# Philadelphia    14569
# Tucson           9250
# Tampa            9050
# Indianapolis     7540
# Nashville        6971
# Name: count, dtype: int64

# %%
#plot value counts
sns.barplot(x = city_valuecounts.index, y = city_valuecounts, palette='vlag')
# Out:
# <Axes: xlabel='city', ylabel='count'>

# %%
#top 10 businesses: according to the star ratings
top_10 =  businness.sort_values('stars', ascending = False).head(10)
top_10
# Out:
#                   business_id                              name  \
# 0      Pns2l4eNsfO8kk83dixA6A          Abby Rappoport, LAC, CMQ
# 60693  aASoTrOuCUd0sw2JcA9KcA           Beautiful Brides Philly
# 60680  Z_l5dmN5AvLDS0KtVEjZZA                     Dogs-N-Donuts
# 60668  kkDAHR0rBwo_KGaPRxHqiw                         Eye Deals
# 60664  0y0qPSILVuwmj-hxkJJ0Bg                   EverybodyFights
# 60661  zovnQ8uG7-hx9_t5lMe8sQ  Christopher Charles Fine Jewelry
# 60655  tMu7rl3TO8MoATdyD6cZ2A           Red Kite Bicycle Studio
# 60646  Yn9zJfQ6ejsj6UFcLBdVXA                          Studio N
# 60615  yKdBTZEoJssmojLNmPrjig                Sea Change Brewing
# 60596  iH-NQNEuEbLCWX1xlBvTng            Salon Basia Hair Salon
#
#                              address             city state postal_code  \
# 0             1616 Chapala St, Ste 2    Santa Barbara    CA       93101
# 60693            1613 E Passyunk Ave     Philadelphia    PA       19148
# ...

# %%
#bottom 10 businesses: according to star ratings
bottom_10 = businness.sort_values('stars', ascending = True).head(10)
bottom_10
# Out:
#                    business_id                      name  \
# 134378  JVPgCc8DPoBquc8_GsCizg             ENT & Allergy
# 133383  7oqr1fVKRNrV1jHPQV1NnQ        Harbourside Resort
# 98006   4U8yH6ieqSEqN29lOzXeVw     Penn State Industries
# 94513   wwcljl_1iVzAip9gspulPw      Florida Shed & Fence
# 101032  69T7PE0VrxhjXZDoeR2mdQ   Ashley Psychic Readings
# 83751   0FgvYpOoxOIIuJd6eFf_kA       J.P Mascaro & Son's
# 52351   CtUUI1uIfsaJ4CzGfArzgw        Thrifty Car Rental
# 128042  qVeRyVCmhUKx36PcY7IEkw  Parc Fontaine Apartments
# 40057   7j-s7IsivJLszx0s0w_QNw             Montego Grill
# 94529   mNB7N7gEf33h9BGWegBHvw                       KFC
#
#                                address                city state postal_code  \
# 134378      1941 Limestone Rd, Ste 210          Wilmington    DE       19808
# 133383                      399 2nd St  Indian Rocks Beach    FL       33785
# 98006                  1425 Carlton St        Philadelphia    PA       19102
# ...

# %%
#average star rating per city
avg_stars_city = businness.groupby('city', as_index=False, sort=False).agg({'stars': ['mean']}).round(2)
avg_stars_city
# Out:
#                 city stars
#                       mean
# 0      Santa Barbara  4.05
# 1             Affton  3.49
# 2             Tucson  3.59
# 3       Philadelphia  3.62
# 4         Green Lane  4.05
# ...              ...   ...
# 1411    Mount Holly,  3.50
# 1412         Slidell  4.00
# 1413           Wales  3.00
# 1414  UPPER MORELAND  4.00
# 1415    Apollo beach  4.50
#
# [1416 rows x 2 columns]

# %%
#let's plot these average results

#choose 10 cities for plotting purposes
avg_stars_city_limit10 = avg_stars_city.head(10)

sns.lineplot(x='city', y=('stars', 'mean'), data=avg_stars_city_limit10, marker='o', color='#dc9c9c')

#add labels and title 
plt.xlabel('City')
plt.ylabel('Average Star Ratings')
plt.title('Average Stars by City')

#rotate x-axis labels
plt.xticks(rotation=45)

#show plot
plt.show()

# %%
#average overall star rating: 3.6
avg_stars = businness.agg({'stars': ['mean']}).round(2)
avg_stars
# Out:
#       stars
# mean    3.6

# %% [markdown]
# ### Recommender systems
# Now let's try to build a simple recommender system
#
# ### *Nota: sistema de recomndação baseado no nome dos negócios. Ainda não experimentei com as ratings/stars de cada estabelecimento*
#
# tutorial: https://thecleverprogrammer.com/2022/07/26/restaurant-recommendation-system-using-python/

# %%
data = businness[['name', 'categories']]
data.head(10)
# Out:
#                                      name  \
# 0  Steps to Learning Montessori Preschool
# 1                     Breeze Blow Dry Bar
# 2                             Impact Guns
# 3                      Palms Primary Care
# 4                               J&Q Nails
# 5                            Candy Barrel
# 6                              Luminosity
# 7                         Nail Care Salon
# 8  Architectural Antiques of Indianapolis
# 9                     Aster's Floral Shop
#
#                                           categories
# 0  Education, Elementary Schools, Child Care & Da...
# 1  Hair Salons, Beauty & Spas, Hair Stylists, Ski...
# 2                      Gun/Rifle Ranges, Active Life
# 3       Internal Medicine, Doctors, Health & Medical
# 4   Nail Salons, Hair Removal, Beauty & Spas, Waxing
# 5                 Candy Stores, Specialty Food, Food
# 6  Cosmetics & Beauty Supply, Cosmetic Dentists, ...
# 7                         Nail Salons, Beauty & Spas
# ...

# %%
#additional imports
from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

feature = data['categories'].astype(str).tolist()  
tfidf = TfidfVectorizer(stop_words="english")
tfidf_matrix = tfidf.fit_transform(feature)
similarity = cosine_similarity(tfidf_matrix)
indices = pd.Series(data.index, index=data['name']).drop_duplicates()

# %%
# recommend similar restaurants
# try to recommend similar businesses to Aster's Floral Shop
def business_recommendation(name, similarity = similarity):
    index = indices[name]
    similarity_scores = list(enumerate(similarity[index]))
    similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)
    similarity_scores = similarity_scores[0:10]
    businessindices = [i[0] for i in similarity_scores]
    return data['name'].iloc[businessindices]

print(business_recommendation("Aster's Floral Shop"))
# Out:
# 9                     Aster's Floral Shop
# 11405                        Flora Savage
# 11899                    Mayfield Florist
# 6412                     Gulfport Florist
# 7898                    Laurel's On Whyte
# 13286                        Funky Petals
# 229                    The Garden of Eden
# 7151                 Southern Floral Shop
# 10400    Something Different...In Flowers
# 10882              Kati Mac Floral Design
# Name: name, dtype: object

# %%
# plot the results!
import matplotlib.pyplot as plt

def plot_recommendations(recommendations):
    plt.figure(figsize=(10, 6))
    plt.barh(recommendations.index, recommendations.values, color='pink')
    plt.xlabel('Similarity Score')
    plt.title('10 Recommended Flower Shops')
    plt.gca().invert_yaxis()  
    plt.show()

recommended_business = business_recommendation("Aster's Floral Shop")

recommended_business = recommended_business[1:]

# Create a Series with similarity scores as values and restaurant names as index
similarity_scores = [similarity[indices["Aster's Floral Shop"], indices[restaurant]] for restaurant in recommended_business]
recommendations_series = pd.Series(similarity_scores, index=recommended_business)

plot_recommendations(recommendations_series)

# %% [markdown]
# ### Trying Sentiment Analysis
